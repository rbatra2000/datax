# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
traffic_df = pd.read_csv('Traffic_Volume_Counts__2014-2019_.csv').dropna().reset_index().drop(columns='index')
traffic_df.tail()
# Out:
#         ID  Segment ID Roadway Name            From               To  \
# 27280  371       37916     3 Avenue  East 99 Street  East 100 Street
# 27281  371       37916     3 Avenue  East 99 Street  East 100 Street
# 27282  371       37916     3 Avenue  East 99 Street  East 100 Street
# 27283  371       37916     3 Avenue  East 99 Street  East 100 Street
# 27284  371       37916     3 Avenue  East 99 Street  East 100 Street
#
#       Direction        Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  \
# 27280        NB  10/16/2019          297.0        155.0        162.0  ...
# 27281        NB  10/17/2019          181.0        107.0         78.0  ...
# 27282        NB  10/18/2019          248.0        161.0        115.0  ...
# 27283        NB  10/19/2019          251.0        195.0        132.0  ...
# 27284        NB  10/20/2019          360.0        277.0        233.0  ...
#
#        2:00-3:00PM  3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  \
# ...

# %%
busiest_streets_id  = [7579, 6379, 6529, 7429, 6531, 7581, 7281, 6829, 14723, 14960, 7131, 6381, 6831,
                          15018, 14783, 12493, 12495, 14724, 15133, 6681, 14902, 15076, 12579, 12940, 12535,14820]

# %%
for i in busiest_streets_id :
    print(traffic_df.iloc[i, 2:6].values)
# Out:
# ['BRONX RIVER PARKWAY' 'BOSTON ROAD' 'ENTRANCE' 'SB']
# ['BRONX RIVER PARKWAY' 'BOSTON ROAD' 'ENTRANCE' 'SB']
# ['BRONX RIVER PARKWAY' 'BOSTON ROAD' 'ENTRANCE' 'SB']
# ['BRONX RIVER PARKWAY' 'BOSTON ROAD' 'ENTRANCE' 'SB']
# ['BRONX RIVER PARKWAY' 'MORRIS PARK AVENUE' 'BRONXDALE AVENUE' 'SB']
# ['BRONX RIVER PARKWAY' 'MORRIS PARK AVENUE' 'BRONXDALE AVENUE' 'SB']
# ['BRONX RIVER PARKWAY' 'MORRIS PARK AVENUE' 'BRONXDALE AVENUE' 'SB']
# ['BRONX RIVER PARKWAY' 'BOSTON ROAD' 'ENTRANCE' 'SB']
# ['STATEN ISLAND EXPRESSWAY' 'RENWICK AVENUE' 'SLOSSON AVENUE' 'EB']
# ['STATEN ISLAND EXPRESSWAY' 'RENWICK AVENUE' 'SLOSSON AVENUE' 'WB']
# ['BRONX RIVER PARKWAY' 'MORRIS PARK AVENUE' 'BRONXDALE AVENUE' 'SB']
# ['BRONX RIVER PARKWAY' 'MORRIS PARK AVENUE' 'BRONXDALE AVENUE' 'SB']
# ['BRONX RIVER PARKWAY' 'MORRIS PARK AVENUE' 'BRONXDALE AVENUE' 'SB']
# ['STATEN ISLAND EXPRESSWAY' 'RENWICK AVENUE' 'SLOSSON AVENUE' 'WB']
# ['STATEN ISLAND EXPRESSWAY' 'RENWICK AVENUE' 'SLOSSON AVENUE' 'EB']
# ...

# %%
latitudes_from = [40.85388401226686, 40.841538057366115, 40.61042808618818, 40.733908, 40.727189,  ]
longitudes_from = [-73.8723424733463, -73.87233329527287, -74.1055221279016, -73.864431, -73.888214]

latitudes_to = [40.82450005848858, 40.855210885714065, 40.61124533506277, 40.734434, 40.727695, ]
longitudes_to = [-73.87249803628636, -73.86985217892148, -74.11674158313213, -73.862678, -73.887212]

names_of_roads = ['Bronx River Parkway [Boston Road - Entrance]', 
                  'Bronx River Parkway [Morris Park Avenue - Bronxdale Avenue]',
                 'Staten Island Expressway [Renwick Avenue - Slosson Avenue]',
                 'Long Island Expressway [Junction Boulevard - 97 Street]',
                 'Long Island Expressway [73 Place - 74 Street]']

# %% [markdown]
# ## Final output

# %%
dictionary_for_df = {'Avenue':names_of_roads, 'Latitude From':latitudes_from, 'Longitude From':longitudes_from,
                    'Latitude to':latitudes_to, 'Longitude to':longitudes_to}

busiest_avenues_df = pd.DataFrame(dictionary_for_df)
busiest_avenues_df
# Out:
#                                               Avenue  Latitude From  \
# 0       Bronx River Parkway [Boston Road - Entrance]      40.853884
# 1  Bronx River Parkway [Morris Park Avenue - Bron...      40.841538
# 2  Staten Island Expressway [Renwick Avenue - Slo...      40.610428
# 3  Long Island Expressway [Junction Boulevard - 9...      40.733908
# 4      Long Island Expressway [73 Place - 74 Street]      40.727189
#
#    Longitude From  Latitude to  Longitude to
# 0      -73.872342    40.824500    -73.872498
# 1      -73.872333    40.855211    -73.869852
# 2      -74.105522    40.611245    -74.116742
# 3      -73.864431    40.734434    -73.862678
# 4      -73.888214    40.727695    -73.887212
